# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

csv_df = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding="latin-1")
csv_df.to_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv')
csv_df.describe(include='all')
# Out:
#            Area Code   Area     Item Code                     Item  \
# count   60943.000000  60943  60943.000000                    60943
# unique           NaN     49           NaN                      119
# top              NaN  Kenya           NaN  Milk - Excluding Butter
# freq             NaN   1560           NaN                     1262
# mean      134.265576    NaN   2687.176706                      NaN
# std        72.605709    NaN    146.055739                      NaN
# min         4.000000    NaN   2501.000000                      NaN
# 25%        74.000000    NaN   2562.000000                      NaN
# 50%       136.000000    NaN   2630.000000                      NaN
# 75%       195.000000    NaN   2775.000000                      NaN
# max       276.000000    NaN   2961.000000                      NaN
#
#         Element Code                   Element         Unit          Y2014  \
# count   60943.000000                     60943        60943   59354.000000
# ...

# %%
csv_df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
csv_df.tail()
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit  Y2014  Y2015  \
# 60938                                    Food      1000 tonnes  42.00  46.00
# 60939     Food supply quantity (kg/capita/yr)               kg   3.06   3.33
# 60940           Food supply (kcal/capita/day)  kcal/capita/day   3.00   4.00
# 60941  Protein supply quantity (g/capita/day)     g/capita/day   0.10   0.11
# 60942      Fat supply quantity (g/capita/day)     g/capita/day   0.04   0.05
#
#        Y2016  Y2017  Y2018
# 60938  33.00  19.00  16.00
# 60939   2.35   1.33   1.08
# ...

# %%
csv_df.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
csv_df.mean()
# Out:
# /var/folders/pz/9zpk255567z7h8w4_dpllzvc0000gn/T/ipykernel_7886/1276477327.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   csv_df.mean()
# Area Code        134.265576
# Item Code       2687.176706
# Element Code    3814.856456
# Y2014            134.196282
# Y2015            135.235966
# Y2016            136.555222
# Y2017            140.917765
# Y2018            143.758381
# dtype: float64

# %%
csv_df.groupby('Y2017')['Y2017'].count()
# Out:
# Y2017
# -1582.0      2
# -1200.0      1
# -1159.0      1
# -865.0       1
# -860.0       1
#             ..
#  96443.0     1
#  106400.0    1
#  112625.0    1
#  117702.0    1
#  190873.0    1
# Name: Y2017, Length: 4537, dtype: int64

# %%
csv_df.groupby(['Y2017']).sum('')
# Out:
#            Area Code                         Area  Item Code  \
# Y2017
# -1582.0          118                   EgyptEgypt       5445
# -1200.0          144                   Mozambique       2532
# -1159.0          144                   Mozambique       2907
# -865.0           215  United Republic of Tanzania       2913
# -860.0           215  United Republic of Tanzania       2556
# ...              ...                          ...        ...
#  96443.0          59                        Egypt       2501
#  106400.0        238                     Ethiopia       2501
#  112625.0        159                      Nigeria       2907
#  117702.0        159                      Nigeria       2907
#  190873.0        159                      Nigeria       2501
#
#                               Item  Element Code  \
# Y2017
# -1582.0      Sugar CropsSugar beet         10144
# -1200.0       Cassava and products          5072
# -1159.0              Starchy Roots          5072
# ...

# %%
csv_df.groupby(['Y2017', 'Area'])['Area'].sum()
# Out:
# Y2017      Area
# -1582.0    Egypt                                           EgyptEgypt
# -1200.0    Mozambique                                      Mozambique
# -1159.0    Mozambique                                      Mozambique
# -865.0     United Republic of Tanzania    United Republic of Tanzania
# -860.0     United Republic of Tanzania    United Republic of Tanzania
#                                                      ...
#  96443.0   Egypt                                                Egypt
#  106400.0  Ethiopia                                          Ethiopia
#  112625.0  Nigeria                                            Nigeria
#  117702.0  Nigeria                                            Nigeria
#  190873.0  Nigeria                                            Nigeria
# Name: Area, Length: 14773, dtype: object

# %%
csv_df.groupby(['Y2017'], sort=True)['Area'].sum()
# Out:
# Y2017
# -1582.0                       EgyptEgypt
# -1200.0                       Mozambique
# -1159.0                       Mozambique
# -865.0       United Republic of Tanzania
# -860.0       United Republic of Tanzania
#                         ...
#  96443.0                           Egypt
#  106400.0                       Ethiopia
#  112625.0                        Nigeria
#  117702.0                        Nigeria
#  190873.0                        Nigeria
# Name: Area, Length: 4537, dtype: object

# %%
csv_df.groupby(['Y2015', 'Y2018'])['Item'].sum()
# Out:
# Y2015      Y2018
# -3161.0    -296.0       Cereals - Excluding Beer
# -2152.0    -597.0             Maize and products
# -1284.0     1898.0      Cereals - Excluding Beer
# -907.0     -529.0       Cereals - Excluding Beer
# -887.0      163.0           Sorghum and products
#                                   ...
#  92443.0    98424.0                   Population
#  100835.0   109224.0                  Population
#  110798.0   117038.0               Starchy Roots
#  111663.0   118172.0               Starchy Roots
#  181137.0   195875.0                  Population
# Name: Item, Length: 14814, dtype: object

# %%
S = [['him', 'sell'], [90, 28, 43]]

print(S[0][1][1])
# Out:
# e
